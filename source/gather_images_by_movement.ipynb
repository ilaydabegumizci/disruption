# %%
import urllib
import re
from bs4 import BeautifulSoup
import time
import os.path
from os import path
import lxml

# %%
movement_list=["baroque"]
#TO-DO : liste güncellenecek

# %%
for movement in movement_list:
    file_path = 'C:/Users/WS2/Desktop/kozmiksefer/disruption/data_set/'+str(movement)
    print(file_path)
    if path.exists(file_path) == False:
      os.makedirs(file_path)
      os.chdir(file_path)
# Out:
# C:/Users/WS2/Desktop/kozmiksefer/disruption/data_set/baroque

# %%
base_url = "https://www.wikiart.org"
# iterate through all artists by last name alphabetically
# like this https://www.wikiart.org/en/Alphabet/m/text-list
for c in range(ord('a'), ord('z') + 1):
  char = chr(c)
  artist_list_url = base_url + "/en/Alphabet/" + char + "/text-list"
  print(artist_list_url)

  genre_soup = BeautifulSoup(urllib.request.urlopen(artist_list_url), "lxml")
  artist_list_main = genre_soup.find("main")
  lis = artist_list_main.find_all("li")

  # for each list element
  for li in lis: 
    born = 0
    died = 0

    # get the date range
    for line in li.text.splitlines():
      if line.startswith(",") and "-" in line:
        parts = line.split('-')
        if len(parts) == 2:
          born = int(re.sub("[^0-9]", "",parts[0]))
          died = int(re.sub("[^0-9]", "",parts[1]))

    link = li.find("a")
    artist = link.attrs["href"]

    # get the artist's main page
    artist_url = base_url + artist
    artist_soup = BeautifulSoup(urllib.request.urlopen(artist_url), "lxml")

    # only look for artists with the word abstract on their main page
    for movement in movement_list:
      if movement in artist_soup.text: 
        print(artist + " " + str(born) + " - " + str(died))
        #artist_soup.text

        # get the artist's web page for the artwork
        url = base_url + artist + '/all-works/text-list'
        artist_work_soup = BeautifulSoup(urllib.request.urlopen(url), "lxml")

        # get the main section
        artist_main = artist_work_soup.find("main")
        image_count = 0
        artist_name = artist.split("/")[2]
        # get the list of artwork
        lis = artist_main.find_all("li")

        # for each list element
        for li in lis:
          link = li.find("a")

          if link != None:
            painting = link.attrs["href"]

            # get the painting
            url = base_url + painting
            print(url)

            try:
              painting_soup = BeautifulSoup(urllib.request.urlopen(url), "lxml")

            except:
              print("error retreiving page")
              continue

            #check the genre
            field = painting_soup.find("span", {"itemprop":"field"})
            if field == None or field.text in field_list:
              print("field :",field)

              # get the url
              og_image = painting_soup.find("meta", {"property":"og:image"})
              image_url = og_image["content"].split("!")[0] # ignore the !Large.jpg at the end
              print(image_url)

              parts = url.split("/")
              painting_name = parts[-1]
              file_path='C:/Users/WS2/Desktop/kozmiksefer/disruption/data_set/'+str(movement)
              save_path = file_path + "/" + artist_name + "_" + painting_name + ".jpg"

              #download the file
              try:
                print("downloading to " + save_path)
                time.sleep(0.2)  # try not to get a 403                    
                urllib.request.urlretrieve(image_url, save_path)
                image_count = image_count + 1
              except Exception as e:
                print("failed downloading " + image_url, e) 
        break
# Out:
# https://www.wikiart.org/en/Alphabet/a/text-list
# https://www.wikiart.org/en/Alphabet/b/text-list
# /en/marcello-bacciarelli 1731 - 1818
# https://www.wikiart.org/en/marcello-bacciarelli/heinrich-graf-von-bruhl-1753
# field : None
# https://uploads3.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-heinrich-graf-von-br-hl.jpeg
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_heinrich-graf-von-bruhl-1753.jpg
# failed downloading https://uploads3.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-heinrich-graf-von-br-hl.jpeg [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_heinrich-graf-von-bruhl-1753.jpg'
# https://www.wikiart.org/en/marcello-bacciarelli
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_cincinnatus1795-1795.jpg
# failed downloading https://uploads4.wikiart.org/00159/images/marcello-bacciarelli/cincinnatus.png [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_cincinnatus1795-1795.jpg'
# https://www.wikiart.org/en/marcello-bacciarelli/sobieski-at-the-battle-of-vienna-1796
# field : None
# https://uploads1.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-sobieski-at-the-battle-of-vienna.jpg
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_sobieski-at-the-battle-of-vienna-1796.jpg
# failed downloading https://uploads1.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-sobieski-at-the-battle-of-vienna.jpg [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_sobieski-at-the-battle-of-vienna-1796.jpg'
# https://www.wikiart.org/en/marcello-bacciarelli/prussian-homage-1796
# field : None
# https://uploads2.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-prussian-homage.PNG
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_prussian-homage-1796.jpg
# failed downloading https://uploads2.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-prussian-homage.PNG [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_prussian-homage-1796.jpg'
# https://www.wikiart.org/en/marcello-bacciarelli/union-of-lublin-1796
# field : None
# https://uploads2.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-union-of-lublin.png
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_union-of-lublin-1796.jpg
# failed downloading https://uploads2.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-union-of-lublin.png [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_union-of-lublin-1796.jpg'
# https://www.wikiart.org/en/marcello-bacciarelli/the-chocim-treaty-1621-1796
# field : None
# https://uploads8.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-treaty-of-khotyn-1621.png
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_the-chocim-treaty-1621-1796.jpg
# failed downloading https://uploads8.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-treaty-of-khotyn-1621.png [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_the-chocim-treaty-1621-1796.jpg'
# https://www.wikiart.org/en/marcello-bacciarelli/granting-privileges-to-the-academy-of-krakow-1796
# field : None
# https://uploads4.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-granting-privileges-to-the-academy-of-krakow.jpg
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_granting-privileges-to-the-academy-of-krakow-1796.jpg
# failed downloading https://uploads4.wikiart.org/00159/images/marcello-bacciarelli/marcello-bacciarelli-granting-privileges-to-the-academy-of-krakow.jpg [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_granting-privileges-to-the-academy-of-krakow-1796.jpg'
# https://www.wikiart.org/en/marcello-bacciarelli/king-casimir-the-great-1796
# field : None
# https://uploads5.wikiart.org/00159/images/marcello-bacciarelli/opera-anl-k-g-r-nt-2017-11-18-195029-www-imnk-pl.png
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_king-casimir-the-great-1796.jpg
# failed downloading https://uploads5.wikiart.org/00159/images/marcello-bacciarelli/opera-anl-k-g-r-nt-2017-11-18-195029-www-imnk-pl.png [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_king-casimir-the-great-1796.jpg'
# https://www.wikiart.org/en/marcello-bacciarelli/anna-lampel-1801
# field : None
# https://uploads7.wikiart.org/00159/images/marcello-bacciarelli/bacciarelli-anna-lampel.jpg
# downloading to /Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_anna-lampel-1801.jpg
# failed downloading https://uploads7.wikiart.org/00159/images/marcello-bacciarelli/bacciarelli-anna-lampel.jpg [Errno 2] No such file or directory: '/Users/iizci/Desktop/kozmik_sefer/data_set/baroque/marcello-bacciarelli_anna-lampel-1801.jpg'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\WS2\Desktop\kozmiksefer\disruption\source\gather_images.ipynb Hücre 4 in <cell line: 4>()
#      <a href='vscode-notebook-cell:/c%3A/Users/WS2/Desktop/kozmiksefer/disruption/source/gather_images.ipynb#W3sZmlsZQ%3D%3D?line=28'>29</a> # get the artist's main page
#      <a href='vscode-notebook-cell:/c%3A/Users/WS2/Desktop/kozmiksefer/disruption/source/gather_images.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a> artist_url = base_url + artist
# ---> <a href='vscode-notebook-cell:/c%3A/Users/WS2/Desktop/kozmiksefer/disruption/source/gather_images.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a> artist_soup = BeautifulSoup(urllib.request.urlopen(artist_url), "lxml")
#      <a href='vscode-notebook-cell:/c%3A/Users/WS2/Desktop/kozmiksefer/disruption/source/gather_images.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a> # only look for artists with the word abstract on their main page
#      <a href='vscode-notebook-cell:/c%3A/Users/WS2/Desktop/kozmiksefer/disruption/source/gather_images.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a> for movement in movement_list:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
